# %%
# This program is coded to describe the wave on a string using PDEs.


# importing the essencial libararies
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


# defining a wave function incial and max position and steps for position and time
def wave(x0,xf,Nx,Nt):
    
    
    # the incial conditions for time
    t0 = 0          
    tf = 10            
    dt = 0.01          
    
    
    # the conditions for the position                         
    
    x = np.linspace(x0, xf, Nx)  # postion array
    
    
    # the function for the wave
    f = np.sin(x)
    
    
    # creating arrays for df and ddf
    df = np.zeros(Nx)
    ddf = np.zeros(Nx)
    
    
    # creating loops to desvribe the wave
    for i in range(Nt):
        for j in range(1, Nx - 1):
            
            ddf[j] = (0.5*(f[j-1] + f[j+1] ) - f[j])
        
        
        df += ddf*dt
        f += df*dt
        
    return f,x

# the graph shows the smoothness as we increase the number of steps for the position
f1,x1 = wave(-np.pi,np.pi,8,100)
f2,x2 = wave(-np.pi,np.pi,15,100)
f3,x3 = wave(-np.pi,np.pi,100,100)
plt.figure(1)

plt.plot(x1,f1, "green")
plt.plot(x2,f2, "red")
plt.plot(x3,f3, "blue")

# %%
# This program is coded to describe the wave on a string using PDEs. 


# importing the essencial libararies
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


# defining a wave function incial and max position and steps for position and time
def wave(x0,xf,Nx,Nt):
    
    
    # the incial conditions for time
    t0 = 0          
    tf = 10            
    dt = 0.01          
    
    
    # the conditions for the position
                             
    
    x = np.linspace(x0, xf, Nx)  # postion array
    
    
    # the function for the wave
    f = np.cos(x)
    
    
    # creating arrays for df and ddf
    df = np.zeros(Nx)
    ddf = np.zeros(Nx)
    
    
    # creating loops to desvribe the wave
    for i in range(Nt):
        for j in range(1, Nx - 1):
            
            ddf[j] = (0.5*(f[j-1] + f[j+1] ) - f[j])
        
        
        df += ddf*dt
        f += df*dt
        
    return f,x

# the graph shows the smoothness as we increase the number of steps for the position
f1,x1 = wave(-np.pi/2,np.pi/2,8,100)
f2,x2 = wave(-np.pi/2,np.pi/2,15,100)
f3,x3 = wave(-np.pi/2,np.pi/2,100,100)
plt.figure(1)

plt.plot(x1,f1, "green")
plt.plot(x2,f2, "red")
plt.plot(x3,f3, "blue")
